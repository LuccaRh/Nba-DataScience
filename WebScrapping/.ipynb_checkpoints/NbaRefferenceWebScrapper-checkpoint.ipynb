# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
dados_jogadores = []

url = 'https://www.basketball-reference.com/leagues/NBA_2024_per_game.html'
response = requests.get(url)

if response.status_code == 200:
    
    soup = BeautifulSoup(response.text, 'html.parser')
    tabela = soup.find('table', {'id': 'per_game_stats'})
    cabecalhos = [th.text.strip() for th in tabela.find('thead').find_all('th')]
    

    for linha in tabela.find('tbody').find_all('tr'):
        dados_jogador = [td.text.strip() for td in linha.find_all('td')]
        jogador = dict(zip(cabecalhos, dados_jogador))
        dados_jogadores.append(jogador)

else:
    print('Falha na solicitação HTTP:', response.status_code)

# %%
df = pd.DataFrame(dados_jogadores)
df.head()
# Out:
#                  Rk Player Pos  Age  Tm   G    GS   MP    FG   FGA  ...   FTA  \
# 0  Precious Achiuwa   C-PF  24  TOT  47   8  20.8  3.2   6.5  .490  ...  .614
# 1  Precious Achiuwa      C  24  TOR  25   0  17.5  3.1   6.8  .459  ...  .571
# 2  Precious Achiuwa     PF  24  NYK  22   8  24.5  3.3   6.2  .529  ...  .733
# 3       Bam Adebayo      C  26  MIA  43  43  34.5  7.6  15.0  .505  ...  .780
# 4      Ochai Agbaji     SG  23  TOT  53  10  19.6  2.1   5.0  .414  ...  .739
#
#    FT%  ORB   DRB  TRB  AST  STL  BLK  TOV    PF
# 0  2.4  3.7   6.1  1.3  0.6  0.8  1.0  1.9   7.5
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.0   7.0  0.7  0.6  1.1  0.9  2.1   7.3
# 3  2.2  8.3  10.6  4.0  1.0  1.0  2.4  2.5  20.3
# 4  0.7  1.8   2.5  0.9  0.5  0.5  0.7  1.3   5.4
#
# [5 rows x 29 columns]
